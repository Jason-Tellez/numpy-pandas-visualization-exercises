# %%
import matplotlib.pyplot as plt
import math as m

# %% [markdown]
# #### Title your chart "Big O Notation"
# #### Label your x axis "Elements"
# #### Label your y axis "Operations"
# #### Label your curves or make a legend for the curves
# #### Use LaTex notation where possible

# %%
x = range(0,11)
a = [0 * n + 1 for n in x]

plt.plot(x, y)

plt.title('O(1)')
plt.show()

# %%
x = range(1, 11)
b = [m.log(n) for n in x]

plt.plot(x, b)

plt.show()

# %%
x = range(1, 11)
c = [n for n in x]

plt.plot(x, c)

plt.show()

# %%
x = range(1, 11)
d = [n * m.log(n) for n in x]

plt.plot(x, d)

plt.show()

# %%
x = range(1, 11)
e = [n * n for n in x]

plt.plot(x, e)

plt.show()

# %%
x = range(1, 11)
f = [2 ** n for n in x]

plt.plot(x, f)

plt.show()

# %%
x = range(1,6)
g = [m.factorial(n) for n in x]

plt.plot(x, g)

plt.show()

# %%
x = range(1,6)
h = [n ** n for n in x]

plt.plot(x, h)

plt.show()

# %%
x = range(-100,100)
y = [(n ** 2) + 5 for n in x]

plt.plot(x, y)

plt.axvline(x=50)
plt.axhline(y=8000)
plt.show()
